# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
hits1 = (0.242, 0.228, 0.180, 0.138, 0.130)  # 'RotatE', 'ConvE', 'DistMult', 'TransE', 'RESCAL'
hits3 = (0.377, 0.336, 0.281, 0.236, 0.136)
hits10 = (0.533, 0.478, 0.407, 0.361, 0.149)

ind = np.arange(5)  # the x locations for the groups
width = 0.4  # the width of the bars

p3 = plt.bar(ind, hits10, width)
p2 = plt.bar(ind, hits3, width)
p1 = plt.bar(ind, hits1, width)

plt.ylabel('HITS@N')
plt.title('HITS@N scores of our models\n(the dashed line shows HITS@10 of the paper)')
plt.xticks(ind, ('RotatE', 'ConvE', 'DistMult', 'TransE', 'RESCAL'))
plt.legend((p1[0], p2[0], p3[0]), ('HITS@1', 'HITS@3', 'HITS@10'))

plt.axes().set_axisbelow(True)
plt.grid()
plt.hlines(y=0.533, xmin=-0.2, xmax=0.2,  linewidth=1.5, color='k', linestyles='dashed')
plt.hlines(y=0.501, xmin=0.8, xmax=1.2,  linewidth=1.5, color='k', linestyles='dashed')
plt.hlines(y=0.419, xmin=1.8, xmax=2.2,  linewidth=1.5, color='k', linestyles='dashed')
plt.hlines(y=0.465, xmin=2.8, xmax=3.2,  linewidth=1.5, color='k', linestyles='dashed')
plt.hlines(y=0.198, xmin=3.8, xmax=4.2,  linewidth=1.5, color='k', linestyles='dashed')

plt.savefig(fname='hits', dpi=1000)
plt.show()

# %%
mrr = (0.339, 0.306, 0.257, 0.118, 0.135)  # 'RotatE', 'ConvE', 'DistMult', 'TransE', 'RESCAL'

ind = np.arange(5)  # the x locations for the groups
width = 0.4  # the width of the bars

p1 = plt.bar(ind, mrr, width)

plt.ylabel('MRR')
plt.title('MRR scores of our models\n(the dashed line shows MRR of the paper)')
plt.xticks(ind, ('RotatE', 'ConvE', 'DistMult', 'TransE', 'RESCAL'))

plt.axes().set_axisbelow(True)
plt.grid()
plt.hlines(y=0.338, xmin=-0.2, xmax=0.2,  linewidth=1.5, color='k', linestyles='dashed')
plt.hlines(y=0.325, xmin=0.8, xmax=1.2,  linewidth=1.5, color='k', linestyles='dashed')
plt.hlines(y=0.241, xmin=1.8, xmax=2.2,  linewidth=1.5, color='k', linestyles='dashed')
plt.hlines(y=0.294, xmin=2.8, xmax=3.2,  linewidth=1.5, color='k', linestyles='dashed')
plt.hlines(y=0.100, xmin=3.8, xmax=4.2,  linewidth=1.5, color='k', linestyles='dashed')
plt.savefig(fname='mrr', dpi=1000)
plt.show()

# %%
mr = (178, 292, 286, 303, 5834)  # 'RotatE', 'ConvE', 'DistMult', 'TransE', 'RESCAL'

ind = np.arange(5)  # the x locations for the groups
width = 0.4  # the width of the bars

p1 = plt.bar(ind, mr, width)

plt.ylabel('MR')
plt.title('MR scores of our models\n(the dashed line shows MR of the paper)')
plt.xticks(ind, ('RotatE', 'ConvE', 'DistMult', 'TransE', 'RESCAL'))

plt.axes().set_axisbelow(True)
plt.grid()
plt.hlines(y=177, xmin=-0.2, xmax=0.2,  linewidth=1.5, color='k', linestyles='dashed')
plt.hlines(y=244, xmin=0.8, xmax=1.2,  linewidth=1.5, color='k', linestyles='dashed')
plt.hlines(y=254, xmin=1.8, xmax=2.2,  linewidth=1.5, color='k', linestyles='dashed')
plt.hlines(y=347, xmin=2.8, xmax=3.2,  linewidth=1.5, color='k', linestyles='dashed')
plt.hlines(y=851, xmin=3.8, xmax=4.2,  linewidth=1.5, color='k', linestyles='dashed')
plt.savefig(fname='mr', dpi=1000)
plt.show()

# %%
labels =  ['train', 'valid', 'test']
sizes = [272115, 17535, 20466]  # train, valid, test
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, shadow=False, startangle=90)
ax1.axis('equal')
plt.title('train / valid / test split')
plt.savefig(fname='split', dpi=1000)
plt.show()

# %%
# head prediction: hits@10 per relation type 
hits10_rotate = {'n:m': 0.47741108619032363, '1:1': 0.6369047619047619, '1:n': 0.17034925160370634, 'n:1': 0.8243801652892562}
hits10_conve = {'n:m': 0.41890419737263695, '1:n': 0.11071513423616061, '1:1': 0.34523809523809523, 'n:1': 0.7665289256198347}
hits10_distmult = {'n:m': 0.3418776033322653, '1:1': 0.1130952380952381, '1:n': 0.08315514373960561, 'n:1': 0.756198347107438}
hits10_transe = {'n:m': 0.18709256844850064, '1:1': 0.5714285714285714, 'n:1': 0.7543859649122807, '1:n': 0.020689655172413793}
hits10_rescal = {'n:m': 0.22037808394745273, 'n:1': 0.2975206611570248, '1:n': 0.05892135899263483, '1:1': 0.4583333333333333}

relation_type_order = ['1:1', '1:n', 'n:1', 'n:m']
rotate_values = [hits10_rotate[relation_type] for relation_type in relation_type_order]
conve_values = [hits10_conve[relation_type] for relation_type in relation_type_order]
distmult_values = [hits10_distmult[relation_type] for relation_type in relation_type_order]
transe_values = [hits10_transe[relation_type] for relation_type in relation_type_order]
rescal_values = [hits10_rescal[relation_type] for relation_type in relation_type_order]

fig, ax = plt.subplots()
ind = np.arange(4)    # the x locations for the groups
width = 0.15         # the width of the bars

p1 = ax.bar(ind, rotate_values, width)
p2 = ax.bar(ind + width, conve_values, width)
p3 = ax.bar(ind + width*2, distmult_values, width)
p4 = ax.bar(ind + width*3, transe_values, width)
p5 = ax.bar(ind + width*4, rescal_values, width)

ax.set_title('HITS@10 per relation type (head prediction)')
ax.set_xticks(ind + width*2)
ax.set_xticklabels(('1:1', '1:n', 'n:1', 'n:m'))

ax.legend((p1[0], p2[0], p3[0], p4[0], p5[0]), ('RotatE', 'ConvE', 'DistMult', 'TransE', 'RESCAL'))
ax.autoscale_view()
# ax.set_axisbelow(True)
# plt.grid()
plt.ylabel('HITS@10')
plt.xlabel('relation type')
plt.savefig(fname='hits_relation_type_head', dpi=1000)
plt.show()

# %%
# tail prediction: hits@10 per relation type 
hits10_rotate = {'n:m': 0.5889138096763857, '1:n': 0.8845331432644333, '1:1': 0.6071428571428571, 'n:1': 0.14256198347107438}
hits10_conve = {'n:m': 0.5409804549823775, '1:n': 0.8541221192682348, '1:1': 0.3273809523809524, 'n:1': 0.10950413223140495}
hits10_distmult = {'n:m': 0.46722204421659724, '1:n': 0.7731052506533619, 'n:1': 0.10537190082644628, '1:1': 0.07142857142857142}
hits10_transe = {'n:m': 0.31029986962190353, '1:n': 0.7908045977011494, '1:1': 0.5238095238095238, 'n:1': 0.03508771929824561}
hits10_rescal = {'n:m': 0.2670938801666133, '1:n': 0.21240199572344975, '1:1': 0.43452380952380953, 'n:1': 0.04338842975206612}

relation_type_order = ['1:1', '1:n', 'n:1', 'n:m']
rotate_values = [hits10_rotate[relation_type] for relation_type in relation_type_order]
conve_values = [hits10_conve[relation_type] for relation_type in relation_type_order]
distmult_values = [hits10_distmult[relation_type] for relation_type in relation_type_order]
transe_values = [hits10_transe[relation_type] for relation_type in relation_type_order]
rescal_values = [hits10_rescal[relation_type] for relation_type in relation_type_order]

fig, ax = plt.subplots()
ind = np.arange(4)    # the x locations for the groups
width = 0.15         # the width of the bars

p1 = ax.bar(ind, rotate_values, width)
p2 = ax.bar(ind + width, conve_values, width)
p3 = ax.bar(ind + width*2, distmult_values, width)
p4 = ax.bar(ind + width*3, transe_values, width)
p5 = ax.bar(ind + width*4, rescal_values, width)

ax.set_title('HITS@10 per relation type (tail prediction)')
ax.set_xticks(ind + width*2)
ax.set_xticklabels(('1:1', '1:n', 'n:1', 'n:m'))

ax.legend((p1[0], p2[0], p3[0], p4[0], p5[0]), ('RotatE', 'ConvE', 'DistMult', 'TransE', 'RESCAL'))
ax.autoscale_view()
# ax.set_axisbelow(True)
# plt.grid()
plt.ylabel('HITS@10')
plt.xlabel('relation type')
plt.savefig(fname='hits_relation_type_tail', dpi=1000)
plt.show()

# %%
# head prediction: mean rank per relation type 
mr_rotate = {'n:m': 138.76661326497918, '1:n': 637.8389166072701, 'n:1': 197.6404958677686, '1:1': 290.0595238095238}
mr_conve = {'n:m': 227.0032041012496, '1:n': 983.9080541696364, 'n:1': 238.55578512396696, '1:1': 608.8809523809524}
mr_distmult = {'n:m': 221.0681832745915, '1:n': 763.7196483725351, 'n:1': 240.18595041322314, '1:1': 329.5952380952381}
mr_transe = {'n:m': 352.348109517601, '1:n': 1645.9977011494252, 'n:1': 296.0175438596491, '1:1': 253.95238095238096}
mr_rescal = {'n:m': 511.73085549503367, '1:n': 1493.1931575196008, 'n:1': 724.7210743801653, '1:1': 737.1785714285714}

relation_type_order = ['1:1', '1:n', 'n:1', 'n:m']
rotate_values = [mr_rotate[relation_type] for relation_type in relation_type_order]
conve_values = [mr_conve[relation_type] for relation_type in relation_type_order]
distmult_values = [mr_distmult[relation_type] for relation_type in relation_type_order]
transe_values = [mr_transe[relation_type] for relation_type in relation_type_order]
rescal_values = [mr_rescal[relation_type] for relation_type in relation_type_order]

fig, ax = plt.subplots()
ind = np.arange(4)    # the x locations for the groups
width = 0.15         # the width of the bars

p1 = ax.bar(ind, rotate_values, width)
p2 = ax.bar(ind + width, conve_values, width)
p3 = ax.bar(ind + width*2, distmult_values, width)
p4 = ax.bar(ind + width*3, transe_values, width)
p5 = ax.bar(ind + width*4, rescal_values, width)

ax.set_title('mean rank per relation type (head prediction)')
ax.set_xticks(ind + width*2)
ax.set_xticklabels(('1:1', '1:n', 'n:1', 'n:m'))

ax.legend((p1[0], p2[0], p3[0], p4[0], p5[0]), ('RotatE', 'ConvE', 'DistMult', 'TransE', 'RESCAL'))
ax.autoscale_view()
# ax.set_axisbelow(True)
# plt.grid()
plt.ylabel('MR')
plt.xlabel('relation type')
plt.savefig(fname='mr_relation_type_head', dpi=1000)
plt.show()

# %%
# tail prediction: mean rank per relation type 
mr_rotate = {'n:m': 116.36981736622877, '1:n': 41.455215015443095, 'n:1': 542.7231404958678, '1:1': 215.70238095238096}
mr_conve = {'n:m': 204.59423261775072, '1:n': 96.66025184129246, 'n:1': 738.3657024793389, '1:1': 638.0416666666666}
mr_distmult = {'n:m': 206.7446972124319, '1:n': 281.832026609646, 'n:1': 841.9938016528926, '1:1': 388.55357142857144}
mr_transe = {'n:m': 254.8846153846154, '1:n': 45.234482758620686, 'n:1': 827.6315789473684, '1:1': 166.14285714285714}
mr_rescal = {'n:m': 425.695994873438, '1:n': 445.2615823235923, 'n:1': 1609.404958677686, '1:1': 805.0654761904761}

relation_type_order = ['1:1', '1:n', 'n:1', 'n:m']
rotate_values = [mr_rotate[relation_type] for relation_type in relation_type_order]
conve_values = [mr_conve[relation_type] for relation_type in relation_type_order]
distmult_values = [mr_distmult[relation_type] for relation_type in relation_type_order]
transe_values = [mr_transe[relation_type] for relation_type in relation_type_order]
rescal_values = [mr_rescal[relation_type] for relation_type in relation_type_order]

fig, ax = plt.subplots()
ind = np.arange(4)    # the x locations for the groups
width = 0.15         # the width of the bars

p1 = ax.bar(ind, rotate_values, width)
p2 = ax.bar(ind + width, conve_values, width)
p3 = ax.bar(ind + width*2, distmult_values, width)
p4 = ax.bar(ind + width*3, transe_values, width)
p5 = ax.bar(ind + width*4, rescal_values, width)

ax.set_title('mean rank per relation type (tail prediction)')
ax.set_xticks(ind + width*2)
ax.set_xticklabels(('1:1', '1:n', 'n:1', 'n:m'))

ax.legend((p1[0], p2[0], p3[0], p4[0], p5[0]), ('RotatE', 'ConvE', 'DistMult', 'TransE', 'RESCAL'))
ax.autoscale_view()
# ax.set_axisbelow(True)
# plt.grid()
plt.ylabel('MR')
plt.xlabel('relation type')
plt.savefig(fname='mr_relation_type_tail', dpi=1000)
plt.show()

# %%
hits1_head = (0.150, 0.130, 0.101, 0.084, 0.047)  # 'RotatE', 'ConvE', 'DistMult', 'TransE', 'RESCAL'
hits1_tail = (0.328, 0.311, 0.259, 0.228, 0.060)
hits3_head = (0.268, 0.225, 0.180, 0.154, 0.095)
hits3_tail = (0.479, 0.448, 0.382, 0.356, 0.124)
hits10_head = (0.424, 0.363, 0.297, 0.264, 0.191)
hits10_tail = (0.639, 0.593, 0.518, 0.488, 0.252)

ind = np.arange(5)  # the x locations for the groups
width = 0.2  # the width of the bars

p3_head = plt.bar(ind, hits10_head, width)
p2_head = plt.bar(ind, hits3_head, width)
p1_head = plt.bar(ind, hits1_head, width)

p3_tail = plt.bar(ind+0.3, hits10_tail, width, color='#1f77b4')
p2_tail = plt.bar(ind+0.3, hits3_tail, width, color='#ff7f0e')
p1_tail = plt.bar(ind+0.3, hits1_tail, width, color='#2ca02c')

plt.ylabel('HITS@N')
plt.title('HITS@N scores of our models\n(left: only head, right: only tail prediction)')
plt.xticks(ind+0.15, ('RotatE', 'ConvE', 'DistMult', 'TransE', 'RESCAL'))
plt.legend((p1_head[0], p2_head[0], p3_head[0]), ('HITS@1', 'HITS@3', 'HITS@10'))

plt.axes().set_axisbelow(True)
plt.grid()

plt.savefig(fname='compare_head_tail', dpi=1000) ###
plt.show()
